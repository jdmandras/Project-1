# %% [markdown]
# This is a sample

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.stats as stats
from datetime import datetime, timedelta

# %%
# Create a file path
data_set = Path("Resources\Crimes_2015toPresent_AndrewsTestFile.csv")
df = pd.read_csv(data_set)
df.head()
# Out:
#    District       Primary Type  Arrest   Date  IUCR               Description  \
# 0         1              ARSON    True  19:06  1090             ATTEMPT ARSON
# 1         6  WEAPONS VIOLATION    True  23:22  143A  UNLAWFUL POSS OF HANDGUN
# 2         6  WEAPONS VIOLATION    True   0:27  143A  UNLAWFUL POSS OF HANDGUN
# 3         6  WEAPONS VIOLATION    True  22:00  143A  UNLAWFUL POSS OF HANDGUN
# 4         6  WEAPONS VIOLATION    True  14:38  143A  UNLAWFUL POSS OF HANDGUN
#
#      Location Description FBI Code  Year   Latitude  Longitude
# 0       CONSTRUCTION SITE        9  2015  41.885874 -87.625284
# 1                  STREET       15  2018  41.750717 -87.638868
# 2                  STREET       15  2018  41.752899 -87.617435
# 3  VEHICLE NON-COMMERCIAL       15  2018  41.758364 -87.617594
# 4                  STREET       15  2018  41.744909 -87.603789

# %%
# Create a file path
data_set = Path("Resources\Crimes_2015toPresent.csv")

# Read in the data. 
df = pd.read_csv(data_set)
df.head()
# Out:
#    District       Primary Type  Arrest                    Date  IUCR  \
# 0       1.0              ARSON    True  10/26/2015 07:06:00 PM  1090
# 1       6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2       6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3       6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4       6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
#
#                 Description    Location Description FBI Code  Year   Latitude  \
# 0             ATTEMPT ARSON       CONSTRUCTION SITE       09  2015  41.885874
# 1  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.750717
# 2  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.752899
# 3  UNLAWFUL POSS OF HANDGUN  VEHICLE NON-COMMERCIAL       15  2018  41.758364
# 4  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.744909
#
#    Longitude
# 0 -87.625284
# 1 -87.638868
# 2 -87.617435
# 3 -87.617594
# ...

# %%
#count the number of arrests per year
total_arrests_per_year = df.groupby('Year').size()
total_arrests_per_year
# Out:
# Year
# 2015     82780
# 2016    127802
# 2017    126245
# 2018    127465
# 2019     58977
# 2020      7144
# 2021      1090
# 2022        83
# 2023      1167
# dtype: int64

# %%
#create a data frame from only 2015
crime_data_2015= df[df["Year"] == 2015]
crime_data_2015.head()
# Out:
#      District Primary Type  Arrest                    Date  IUCR  \
# 0         1.0        ARSON    True  10/26/2015 07:06:00 PM  1090
# 416       7.0      ASSAULT    True  09/16/2015 10:33:00 PM  0560
# 417       7.0      ASSAULT    True  09/16/2015 02:35:00 PM  0520
# 418       7.0      ASSAULT    True  09/13/2015 05:30:00 PM  0560
# 419       7.0      ASSAULT    True  09/13/2015 10:35:00 AM  0560
#
#                         Description Location Description FBI Code  Year  \
# 0                     ATTEMPT ARSON    CONSTRUCTION SITE       09  2015
# 416                          SIMPLE            APARTMENT      08A  2015
# 417  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE      04A  2015
# 418                          SIMPLE            APARTMENT      08A  2015
# 419                          SIMPLE   GROCERY FOOD STORE      08A  2015
#
#       Latitude  Longitude
# 0    41.885874 -87.625284
# 416  41.777310 -87.640803
# 417  41.773729 -87.648272
# 418  41.793543 -87.642707
# ...

# %%
crime_data_2015['Date']=pd.to_datetime(crime_data_2015('Date'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 crime_data_2015['Date']=pd.to_datetime(crime_data_2015('Date'))
#
# TypeError: 'DataFrame' object is not callable

# %%
#Display Data Frame (Date, IUCR, Primary Type, Description, Location Description, Arrest, District, FBI Code, Year, Latitude, Longitude)
crime_data = df[["Date","IUCR","Primary Type", "Description", "Location Description", "Arrest", "District", "FBI Code", "Year", "Latitude", "Longitude"]]
crime_data
# Out:
#          Date  IUCR       Primary Type               Description  \
# 0       19:06  1090              ARSON             ATTEMPT ARSON
# 1       23:22  143A  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN
# 2        0:27  143A  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN
# 3       22:00  143A  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN
# 4       14:38  143A  WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN
# ...       ...   ...                ...                       ...
# 532748   8:00   820              THEFT            $500 AND UNDER
# 532749  11:00   810              THEFT                 OVER $500
# 532750   3:00   810              THEFT                 OVER $500
# 532751  14:00   810              THEFT                 OVER $500
# 532752  15:00   890              THEFT             FROM BUILDING
#
#                      Location Description  Arrest  District FBI Code  Year  \
# 0                       CONSTRUCTION SITE    True         1        9  2015
# ...

# %%
#Drop Rows where Year = 2015
crime_data_2015 = crime_data[crime_data["Year"] == 2015]
crime_data_2015.head()
# Out:
#       Date  IUCR Primary Type                     Description  \
# 0    19:06  1090        ARSON                   ATTEMPT ARSON
# 416  22:33   560      ASSAULT                          SIMPLE
# 417  14:35   520      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR
# 418  17:30   560      ASSAULT                          SIMPLE
# 419  10:35   560      ASSAULT                          SIMPLE
#
#     Location Description  Arrest  District FBI Code  Year   Latitude  \
# 0      CONSTRUCTION SITE    True         1        9  2015  41.885874
# 416            APARTMENT    True         7      08A  2015  41.777310
# 417            RESIDENCE    True         7      04A  2015  41.773729
# 418            APARTMENT    True         7      08A  2015  41.793543
# 419   GROCERY FOOD STORE    True         7      08A  2015  41.787147
#
#      Longitude
# 0   -87.625284
# 416 -87.640803
# 417 -87.648272
# 418 -87.642707
# 419 -87.637969

# %%
#get just the dates column seperated
crime_data_2015['Date']
# Out:
# 0         19:06
# 416       22:33
# 417       14:35
# 418       17:30
# 419       10:35
#           ...
# 532748     8:00
# 532749    11:00
# 532750     3:00
# 532751    14:00
# 532752    15:00
# Name: Date, Length: 82780, dtype: object

# %%
from datetime import datetime, timedelta

# %%
df1 = pd.crime_data_2015['Date']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df1 = pd.crime_data_2015['Date']
#
# File c:\Users\Computer\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'crime_data_2015'

# %%
#TEST HERE
crime_data_2015['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 2
#       1 #TEST HERE
# ----> 2 crime_data_2015['Date'] = pd.to_datetime(df['Date'])
#
# File c:\Users\Computer\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\Computer\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
# ...

# %%
population1 = crime_data_2015[crime_data_2015["Date"] == 1]
population1.mean()
# Out:
# Date                    NaN
# IUCR                    NaN
# Primary Type            NaN
# Description             NaN
# Location Description    NaN
# Arrest                  NaN
# District                NaN
# FBI Code                NaN
# Year                    NaN
# Latitude                NaN
# Longitude               NaN
# dtype: object
