# %% [markdown]
# This is a sample

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.stats as stats

# %%
# Create a file path
crimes=pd.read_csv("Resources\Crimes_2015toPresent.csv")
crimes.head()
# Out:
#    District       Primary Type  Arrest                    Date  IUCR  \
# 0       1.0              ARSON    True  10/26/2015 07:06:00 PM  1090
# 1       6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2       6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3       6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4       6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
#
#                 Description    Location Description FBI Code  Year   Latitude  \
# 0             ATTEMPT ARSON       CONSTRUCTION SITE       09  2015  41.885874
# 1  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.750717
# 2  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.752899
# 3  UNLAWFUL POSS OF HANDGUN  VEHICLE NON-COMMERCIAL       15  2018  41.758364
# 4  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.744909
#
#    Longitude
# 0 -87.625284
# 1 -87.638868
# 2 -87.617435
# 3 -87.617594
# ...

# %%
# Create a file path
data_set = Path("Resources\Crimes_2015toPresent.csv")

# Read in the data. 
df = pd.read_csv(data_set)
df.head()
# Out:
#    District       Primary Type  Arrest                    Date  IUCR  \
# 0       1.0              ARSON    True  10/26/2015 07:06:00 PM  1090
# 1       6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2       6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3       6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4       6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
#
#                 Description    Location Description FBI Code  Year   Latitude  \
# 0             ATTEMPT ARSON       CONSTRUCTION SITE       09  2015  41.885874
# 1  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.750717
# 2  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.752899
# 3  UNLAWFUL POSS OF HANDGUN  VEHICLE NON-COMMERCIAL       15  2018  41.758364
# 4  UNLAWFUL POSS OF HANDGUN                  STREET       15  2018  41.744909
#
#    Longitude
# 0 -87.625284
# 1 -87.638868
# 2 -87.617435
# 3 -87.617594
# ...

# %%
#DO NOT USE ONLY A TEST!!! # Calculate the population mean for year
population1 = df[df["Year"] == 2018]
population1.Year.mean()
# Out:
# 2018.0

# %%
#DO NOT USE ONLY A TEST!!! # Calculate the population mean for year that arrests are false
population1 = df[df["Arrest"] == False]
population1.Year.mean()
# Out:
# 2017.010238410081

# %%
#count the number of arrests per year
total_arrests_per_year = crimes.groupby('Year').size()
total_arrests_per_year
# Out:
# Year
# 2015     82780
# 2016    127802
# 2017    126245
# 2018    127465
# 2019     58977
# 2020      7144
# 2021      1090
# 2022        83
# 2023      1167
# dtype: int64

# %%
#plot the number of arrests per year
total_arrests_per_year.plot(kind='bar', color= 'r', alpha=0.5, align="edge")
plt.xticks(rotation="vertical")
plt.xlabel("Year")
plt.ylabel("Total Arrests Made")
plt.title("Total Arrests Made per Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#create a data frame from only 2015
crime_data_filteredyears = crimes[crimes["Year"] == 2015]
crime_data_filteredyears.head()
# Out:
#      District Primary Type  Arrest                    Date  IUCR  \
# 0         1.0        ARSON    True  10/26/2015 07:06:00 PM  1090
# 416       7.0      ASSAULT    True  09/16/2015 10:33:00 PM  0560
# 417       7.0      ASSAULT    True  09/16/2015 02:35:00 PM  0520
# 418       7.0      ASSAULT    True  09/13/2015 05:30:00 PM  0560
# 419       7.0      ASSAULT    True  09/13/2015 10:35:00 AM  0560
#
#                         Description Location Description FBI Code  Year  \
# 0                     ATTEMPT ARSON    CONSTRUCTION SITE       09  2015
# 416                          SIMPLE            APARTMENT      08A  2015
# 417  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE      04A  2015
# 418                          SIMPLE            APARTMENT      08A  2015
# 419                          SIMPLE   GROCERY FOOD STORE      08A  2015
#
#       Latitude  Longitude
# 0    41.885874 -87.625284
# 416  41.777310 -87.640803
# 417  41.773729 -87.648272
# 418  41.793543 -87.642707
# ...

# %%
#Arrests made per crime (Primary Type)
total_arrests_per_crime = crimes[crimes['Arrest'] == True].groupby('Primary Type').size()
total_arrests_per_crime
# Out:
# Primary Type
# ARSON                                  166
# ASSAULT                              14417
# BATTERY                              42556
# BURGLARY                              2542
# CONCEALED CARRY LICENSE VIOLATION      365
# CRIM SEXUAL ASSAULT                    453
# CRIMINAL DAMAGE                       7015
# CRIMINAL SEXUAL ASSAULT                 15
# CRIMINAL TRESPASS                    16042
# DECEPTIVE PRACTICE                    3526
# GAMBLING                               813
# HOMICIDE                                30
# HUMAN TRAFFICKING                        4
# INTERFERENCE WITH PUBLIC OFFICER      4571
# INTIMIDATION                            65
# KIDNAPPING                              54
# LIQUOR LAW VIOLATION                   965
# MOTOR VEHICLE THEFT                   3376
# NARCOTICS                            57632
# NON - CRIMINAL                           4
# NON-CRIMINAL                             7
# ...

# %%
#Display Data Frame (Date, IUCR, Primary Type, Description, Location Description, Arrest, District, FBI Code, Year, Latitude, Longitude)
crime_data = crimes[["Date","IUCR","Primary Type", "Description", "Location Description", "Arrest", "District", "FBI Code", "Year", "Latitude", "Longitude"]]
crime_data
# Out:
#                           Date  IUCR       Primary Type  \
# 0       10/26/2015 07:06:00 PM  1090              ARSON
# 1       10/09/2018 11:22:00 PM  143A  WEAPONS VIOLATION
# 2       10/09/2018 12:27:00 AM  143A  WEAPONS VIOLATION
# 3       10/08/2018 10:00:00 PM  143A  WEAPONS VIOLATION
# 4       10/08/2018 02:38:00 PM  143A  WEAPONS VIOLATION
# ...                        ...   ...                ...
# 532748  03/23/2015 08:00:00 AM  0820              THEFT
# 532749  07/01/2015 11:00:00 AM  0810              THEFT
# 532750  03/24/2015 03:00:00 AM  0810              THEFT
# 532751  03/18/2015 02:00:00 PM  0810              THEFT
# 532752  04/11/2015 03:00:00 PM  0890              THEFT
#
#                      Description               Location Description  Arrest  \
# 0                  ATTEMPT ARSON                  CONSTRUCTION SITE    True
# 1       UNLAWFUL POSS OF HANDGUN                             STREET    True
# ...

# %%
#Drop Rows where Year = 2015
crime_data_filteredyears_2015 = crime_data[crime_data["Year"] == 2015]
crime_data_filteredyears_2015.head()
# Out:
#                        Date  IUCR Primary Type  \
# 0    10/26/2015 07:06:00 PM  1090        ARSON
# 416  09/16/2015 10:33:00 PM  0560      ASSAULT
# 417  09/16/2015 02:35:00 PM  0520      ASSAULT
# 418  09/13/2015 05:30:00 PM  0560      ASSAULT
# 419  09/13/2015 10:35:00 AM  0560      ASSAULT
#
#                         Description Location Description  Arrest  District  \
# 0                     ATTEMPT ARSON    CONSTRUCTION SITE    True       1.0
# 416                          SIMPLE            APARTMENT    True       7.0
# 417  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE    True       7.0
# 418                          SIMPLE            APARTMENT    True       7.0
# 419                          SIMPLE   GROCERY FOOD STORE    True       7.0
#
#     FBI Code  Year   Latitude  Longitude
# 0         09  2015  41.885874 -87.625284
# 416      08A  2015  41.777310 -87.640803
# 417      04A  2015  41.773729 -87.648272
# 418      08A  2015  41.793543 -87.642707
# ...

# %%
#This is just a test to parce out Date/time
df['Date'] = pd.to_time(df['{Date}'], format='%I-%p')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df['Date'] = pd.to_time(df['{Date}'], format='%I-%p')
#
# File c:\Users\Computer\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_time'

# %%
#Arrests made per crime (Primary Type) in only 2015 were arrests are true
total_arrests_per_crime_2015 = crime_data_filteredyears_2015[crime_data_filteredyears_2015['Arrest'] == True].groupby('Primary Type').size()
total_arrests_per_crime_2015
# Out:
# Primary Type
# ARSON                                   33
# ASSAULT                               2399
# BATTERY                               6942
# BURGLARY                               481
# CONCEALED CARRY LICENSE VIOLATION       20
# CRIM SEXUAL ASSAULT                     87
# CRIMINAL DAMAGE                       1139
# CRIMINAL SEXUAL ASSAULT                  2
# CRIMINAL TRESPASS                     2532
# DECEPTIVE PRACTICE                     620
# GAMBLING                               210
# HOMICIDE                                 6
# HUMAN TRAFFICKING                        1
# INTERFERENCE WITH PUBLIC OFFICER       736
# INTIMIDATION                            10
# KIDNAPPING                              10
# LIQUOR LAW VIOLATION                   174
# MOTOR VEHICLE THEFT                    595
# NARCOTICS                            12423
# NON - CRIMINAL                           2
# NON-CRIMINAL                             2
# ...
