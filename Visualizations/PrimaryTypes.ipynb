# %% [markdown]
# Primary Type Arrested by Year

# %%
# import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#import csv file
crimes_data = pd.read_csv('../Resources/Crimes_2015toPresent.csv')

crimes_data
# Out:
#         District       Primary Type  Arrest                    Date  IUCR  \
# 0            1.0              ARSON    True  10/26/2015 07:06:00 PM  1090
# 1            6.0  WEAPONS VIOLATION    True  10/09/2018 11:22:00 PM  143A
# 2            6.0  WEAPONS VIOLATION    True  10/09/2018 12:27:00 AM  143A
# 3            6.0  WEAPONS VIOLATION    True  10/08/2018 10:00:00 PM  143A
# 4            6.0  WEAPONS VIOLATION    True  10/08/2018 02:38:00 PM  143A
# ...          ...                ...     ...                     ...   ...
# 532748      16.0              THEFT   False  03/23/2015 08:00:00 AM  0820
# 532749      16.0              THEFT   False  07/01/2015 11:00:00 AM  0810
# 532750      16.0              THEFT   False  03/24/2015 03:00:00 AM  0810
# 532751      16.0              THEFT   False  03/18/2015 02:00:00 PM  0810
# 532752      16.0              THEFT   False  04/11/2015 03:00:00 PM  0890
#
#                      Description               Location Description FBI Code  \
# ...

# %%
# Full data breakdown of Primary Type occurrences
crimes_dataPT = crimes_data.groupby("Primary Type").size()
crimes_dataPT
# Out:
# Primary Type
# ARSON                                   630
# ASSAULT                               33550
# BATTERY                               88872
# BURGLARY                              17725
# CONCEALED CARRY LICENSE VIOLATION       368
# CRIM SEXUAL ASSAULT                    1952
# CRIMINAL DAMAGE                       37204
# CRIMINAL SEXUAL ASSAULT                  94
# CRIMINAL TRESPASS                     19021
# DECEPTIVE PRACTICE                    29658
# GAMBLING                                813
# HOMICIDE                                 31
# HUMAN TRAFFICKING                        14
# INTERFERENCE WITH PUBLIC OFFICER       4646
# INTIMIDATION                            281
# KIDNAPPING                              250
# LIQUOR LAW VIOLATION                    967
# MOTOR VEHICLE THEFT                   18944
# NARCOTICS                             57647
# NON - CRIMINAL                            5
# NON-CRIMINAL                             81
# ...

# %%
AllPT = pd.DataFrame(crimes_dataPT)
AllPT.columns = ["Total Crimes Occurred"]
AllPT = AllPT.sort_values(by="Total Crimes Occurred",ascending=True)
AllPT
# Out:
#                                    Total Crimes Occurred
# Primary Type
# NON-CRIMINAL (SUBJECT SPECIFIED)                       2
# NON - CRIMINAL                                         5
# HUMAN TRAFFICKING                                     14
# OTHER NARCOTIC VIOLATION                              16
# HOMICIDE                                              31
# PUBLIC INDECENCY                                      47
# NON-CRIMINAL                                          81
# CRIMINAL SEXUAL ASSAULT                               94
# OBSCENITY                                            227
# KIDNAPPING                                           250
# INTIMIDATION                                         281
# STALKING                                             343
# CONCEALED CARRY LICENSE VIOLATION                    368
# ARSON                                                630
# GAMBLING                                             813
# ...

# %%
#plot the number of primary types per year
AllPT.plot(kind='barh', color= 'r', alpha=0.5, align="edge", width=0.8)
plt.xticks(rotation='horizontal')
plt.yticks(rotation = 'horizontal')
plt.xlabel("Primary Type")
plt.ylabel("Total Crimes Occurred")
plt.title("Total Crimes Made per Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a Data Frame for each year
year2015 = crimes_data[crimes_data["Year"] == 2015]
year2015
# Out:
#         District Primary Type  Arrest                    Date  IUCR  \
# 0            1.0        ARSON    True  10/26/2015 07:06:00 PM  1090
# 416          7.0      ASSAULT    True  09/16/2015 10:33:00 PM  0560
# 417          7.0      ASSAULT    True  09/16/2015 02:35:00 PM  0520
# 418          7.0      ASSAULT    True  09/13/2015 05:30:00 PM  0560
# 419          7.0      ASSAULT    True  09/13/2015 10:35:00 AM  0560
# ...          ...          ...     ...                     ...   ...
# 532748      16.0        THEFT   False  03/23/2015 08:00:00 AM  0820
# 532749      16.0        THEFT   False  07/01/2015 11:00:00 AM  0810
# 532750      16.0        THEFT   False  03/24/2015 03:00:00 AM  0810
# 532751      16.0        THEFT   False  03/18/2015 02:00:00 PM  0810
# 532752      16.0        THEFT   False  04/11/2015 03:00:00 PM  0890
#
#                            Description               Location Description  \
# 0                        ATTEMPT ARSON                  CONSTRUCTION SITE
# ...

# %%
# yearly breakdown of Primary Type occurrences
year2015PT = year2015.groupby("Primary Type").size()
year2015PT
# Out:
# Primary Type
# ARSON                                  119
# ASSAULT                               4883
# BATTERY                              14072
# BURGLARY                              2859
# CONCEALED CARRY LICENSE VIOLATION       20
# CRIM SEXUAL ASSAULT                    319
# CRIMINAL DAMAGE                       6025
# CRIMINAL SEXUAL ASSAULT                  3
# CRIMINAL TRESPASS                     2869
# DECEPTIVE PRACTICE                    2922
# GAMBLING                               210
# HOMICIDE                                 6
# HUMAN TRAFFICKING                        2
# INTERFERENCE WITH PUBLIC OFFICER       749
# INTIMIDATION                            32
# KIDNAPPING                              29
# LIQUOR LAW VIOLATION                   175
# MOTOR VEHICLE THEFT                   2835
# NARCOTICS                            12427
# NON - CRIMINAL                           3
# NON-CRIMINAL                            11
# ...
